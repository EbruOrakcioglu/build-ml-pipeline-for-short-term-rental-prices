# %%
import wandb
import pandas as pd

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# /opt/miniconda3/envs/nyc_airbnb_dev/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /opt/miniconda3/envs/nyc_airbnb_dev/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: Currently logged in as: ebru95orakcioglu (ebru95orakcioglu-hacettepe-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.2s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/eorakcioglu/Desktop/projects/udacity/build-ml-pipeline-for-short-term-rental-prices/src/eda/wandb/run-20260210_142406-7bq649ro</code>
# Syncing run <strong><a href='https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb/runs/7bq649ro' target="_blank">efficient-monkey-10</a></strong> to <a href='https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb' target="_blank">https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb/runs/7bq649ro' target="_blank">https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb/runs/7bq649ro</a>

# %%
import ydata_profiling

profile = ydata_profiling.ProfileReport(df)

# %%
profile.to_file("report.html")
# Out:
# Summarize dataset:  78%|███████████████████████████████████████▉           | 18/23 [00:01<00:00, 17.19it/s, Calculate auto correlation]/opt/miniconda3/envs/nyc_airbnb_dev/lib/python3.11/site-packages/ydata_profiling/model/correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Queens'')
#   warnings.warn(
# Summarize dataset:  96%|█████████████████████████████████████████████████▉  | 121/126 [00:09<00:00,  6.53it/s, Missing diagram heatmap]/opt/miniconda3/envs/nyc_airbnb_dev/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# /opt/miniconda3/envs/nyc_airbnb_dev/lib/python3.11/site-packages/ydata_profiling/model/missing.py:78: UserWarning: There was an attempt to generate the Heatmap missing values diagrams, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(missing_diagrams={"Heatmap": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: '--'')
#   warnings.warn(
# Summarize dataset: 100%|██████████████████████████████████████████████████████████████████| 126/126 [00:09<00:00, 12.98it/s, Completed]
# Generate report structure: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.38s/it]
# Render HTML: 100%|███████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.94s/it]
# Export report to file: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 105.74it/s]

# %%
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()

# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">efficient-monkey-10</strong> at: <a href='https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb/runs/7bq649ro' target="_blank">https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb/runs/7bq649ro</a><br> View project at: <a href='https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb' target="_blank">https://wandb.ai/ebru95orakcioglu-hacettepe-university/nyc_airbnb</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260210_142406-7bq649ro/logs</code>
